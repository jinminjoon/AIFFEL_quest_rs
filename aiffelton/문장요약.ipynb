# %%
# 테스트
test_sentences = [
    "나는 아침일찍 운동을 가서 2시간 열심히 운동을해서 그런지 배가 고프다",
    "나는 일주일간 시험공부를 위해 매일 12시간씩 공부를해서 A+를 받았다",
    "나는 다이어트를 진행한 후 엄청 잘생겨졌다"
]

# %%
from keybert import KeyBERT

kw_model = KeyBERT('distilbert-base-nli-mean-tokens')
keywords = kw_model.extract_keywords("나는 아침일찍 운동을 가서 2시간 열심히 운동을해서 그런지 배가 고프다.", keyphrase_ngram_range=(1, 2), stop_words=None)
print(keywords)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.02k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/550 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/265M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [('운동을해서 그런지', 0.9067), ('열심히 운동을해서', 0.8989), ('운동을 가서', 0.8791), ('운동을해서', 0.8626), ('배가 고프다', 0.86)]

# %%
import pytextrank

def extract_keywords_with_textrank(text):
    import spacy
    nlp = spacy.load("en_core_web_sm")
    nlp.add_pipe("textrank")
    doc = nlp(text)
    return [phrase.text for phrase in doc._.phrases[:1]]

keywords = extract_keywords_with_textrank("나는 아침일찍 운동을 가서 2시간 열심히 운동을해서 그런지 배가 고프다.")
print(keywords)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# ['배가 고프다']

# %%
import pytextrank

def extract_keywords_with_textrank(text):
    import spacy
    nlp = spacy.load("en_core_web_sm")
    nlp.add_pipe("textrank")
    doc = nlp(text)
    return [phrase.text for phrase in doc._.phrases[:1]]

keywords = extract_keywords_with_textrank("나는 시험에서 100점을 받았다.")
print(keywords)
# Out:
# ['100점을']

# %%
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# 요약 결과:
#
#  uummarize:
